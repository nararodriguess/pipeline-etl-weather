# %%
import pandas as pd
import json

# %%
path = 'data/raw_data.json'

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 801, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id          name  cod  coord.lon  coord.lat  \
# 0  1780856180    -10800  3457153  Minas Gerais  200        -44        -18
#
#    main.temp  main.feels_like  main.temp_min  main.temp_max  main.pressure  \
# 0      22.37            21.42          22.37          22.37           1015
#
#    main.humidity  main.sea_level  main.grnd_level  wind.speed  wind.deg  \
# 0             29            1015              910        0.61       277
#
#    wind.gust  clouds.all sys.country  sys.sunrise  sys.sunset
# 0       1.81          12          BR   1780824151  1780864049
